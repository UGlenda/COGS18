# %% [markdown]
# # COGS18 Final Project
# ## Glenda R. Utsler
# ### Glenda Utsler's final project for COGS 18, University of California San Diego (UCSD).
#
# ## About this Project
#
# ##### The goal of this project is to implement C.R.U.D. operations (Create, Read, Update, Delete) using Python and Jupyter Notebook. The data that this project focuses on are of musical scores. It will be adapted after submission for other key tabs-- specifically, for the Kalimba; a handheld percussion instrument originating from Zimbabwe.
#
# ##### The inspiration for this project comes from a personal need for managing a collection of music charts. The needs that this project addresses are as follows:
#
#     Tests with Imported Music Database Collection
#     Create, Read, Update, Delete music_list Features
#     Sort Feature (General Queries)
#     Song Randomizer
#     Ability to Delete All Info (to start over with an empty database)
#     CRUD.py, SongRandomizerClass.py
#
# ### How to Run the Project
#
# *Required Packages*
# - pandas
# - pytest
# - jupyter
#
# run the following in terminal to install if the packages above respectively:
# \
# ``` pip install pandas ```
# \
# ``` pip install pytest ```
# \
# ``` pip install jupyter ```
#
# *Running the Program*
# 1. Extract the project.
# 2. In terminal / command line, navigate to the project directory.
# 3. Type ```jupyter notebook``` then press enter to display the project in a browser.
# 4. Open the Glenda_Utsler_COGS18_Final_Project.ipynb file.
# 5. Reload and run all cells.
#
# *Testing the Program*
# 1. There are three (3) test cases. These cases can be found in the project folder under "*/modules/".
# 2. Navigate to this directory in terminal, then run ```pytest``` to see the output.
#
# ### Next Steps
#
#     Add a transcribing feature to simplify sheet music into letter and number notation for the kalimba.
#
# ### Work Used
#
#     Citations for the work used can be found at the end of this document.

# %%
import pandas as pd
from module.functions import *
from module.classes import CRUD

music_list = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/1167622/1956211/musicnet_metadata.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20231211%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20231211T043119Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...')

# %% [markdown]
# ### Data Ingestion

# %%
music_list.columns
# Out:
# Index(['id', 'composer', 'composition', 'movement', 'ensemble', 'source',
#        'transcriber', 'catalog_name', 'seconds'],
#       dtype='object')

# %%
music_list.drop(columns = ['catalog_name', 'source', 'id'], inplace=True)

# %%
music_list = CRUD(music_list)
print (music_list.dtypes)
# Out:
# composer       object
# composition    object
# movement       object
# ensemble       object
# transcriber    object
# seconds         int64
# dtype: object

# %% [markdown]
# ###

# %% [markdown]
# ## Operations

# %% [markdown]
# ### Create

# %%
music_list = CRUD(music_list.create({'composer':['Chopin'], 'composition':['Ballade in G minor'], 'movement':['4. Sonata'], 'ensemble':['Solo Piano'], 'transcriber':['https://RosiStreams.com'], 'seconds':420}))

# %%
print(music_list)
# Out:
#       composer                     composition                   movement  \
# 0     Schubert        Piano Quintet in A major                 2. Andante
# 1     Schubert        Piano Quintet in A major         3. Scherzo: Presto
# 2     Schubert        Piano Quintet in A major  4. Andantino - Allegretto
# 3     Schubert        Piano Quintet in A major          5. Allegro giusto
# 4     Schubert         Piano Sonata in A major               2. Andantino
# ..         ...                             ...                        ...
# 326  Beethoven   Piano Sonata No 10 in G major  3. Scherzo: Allegro assai
# 327       Bach  Violin Partita No 1 in B minor                  6. Double
# 328  Beethoven    Piano Sonata No 9 in E major                 1. Allegro
# 329  Beethoven   Piano Sonata No 10 in G major                 1. Allegro
# 330     Chopin              Ballade in G minor                  4. Sonata
#
#           ensemble                      transcriber  seconds
# 0    Piano Quintet  http://tirolmusic.blogspot.com/      447
# 1    Piano Quintet  http://tirolmusic.blogspot.com/      251
# 2    Piano Quintet  http://tirolmusic.blogspot.com/      444
# 3    Piano Quintet  http://tirolmusic.blogspot.com/      368
# 4       Solo Piano                Segundo G. Yogore      546
# ..             ...                              ...      ...
# 326     Solo Piano                    piano-midi.de      227
# 327    Solo Violin                         suzumidi      108
# 328     Solo Piano                    piano-midi.de      445
# 329     Solo Piano                    piano-midi.de      472
# 330     Solo Piano          https://RosiStreams.com      420
#
# [331 rows x 6 columns]

# %% [markdown]
# ### Read

# %%
music_list.read()
# Out:
#       composer                     composition                   movement  \
# 0     Schubert        Piano Quintet in A major                 2. Andante
# 1     Schubert        Piano Quintet in A major         3. Scherzo: Presto
# 2     Schubert        Piano Quintet in A major  4. Andantino - Allegretto
# 3     Schubert        Piano Quintet in A major          5. Allegro giusto
# 4     Schubert         Piano Sonata in A major               2. Andantino
# ..         ...                             ...                        ...
# 326  Beethoven   Piano Sonata No 10 in G major  3. Scherzo: Allegro assai
# 327       Bach  Violin Partita No 1 in B minor                  6. Double
# 328  Beethoven    Piano Sonata No 9 in E major                 1. Allegro
# 329  Beethoven   Piano Sonata No 10 in G major                 1. Allegro
# 330     Chopin              Ballade in G minor                  4. Sonata
#
#           ensemble                      transcriber  seconds
# 0    Piano Quintet  http://tirolmusic.blogspot.com/      447
# 1    Piano Quintet  http://tirolmusic.blogspot.com/      251
# 2    Piano Quintet  http://tirolmusic.blogspot.com/      444
# 3    Piano Quintet  http://tirolmusic.blogspot.com/      368
# 4       Solo Piano                Segundo G. Yogore      546
# ..             ...                              ...      ...
# 326     Solo Piano                    piano-midi.de      227
# 327    Solo Violin                         suzumidi      108
# 328     Solo Piano                    piano-midi.de      445
# 329     Solo Piano                    piano-midi.de      472
# 330     Solo Piano          https://RosiStreams.com      420
#
# [331 rows x 6 columns]

# %% [markdown]
# ### Update

# %%
# The row to update:
music_list.iloc[329] = ({'composer':'Chopin', 'composition':'Ballade in G minor', 'movement':'4. Sonata', 'ensemble':'Solo Piano', 'transcriber':'https://RosiStreams.com', 'seconds':420})

# %%
music_list.tail(3)
# Out:
#       composer                   composition    movement    ensemble  \
# 328  Beethoven  Piano Sonata No 9 in E major  1. Allegro  Solo Piano
# 329     Chopin            Ballade in G minor   4. Sonata  Solo Piano
# 330     Chopin            Ballade in G minor   4. Sonata  Solo Piano
#
#                  transcriber  seconds
# 328            piano-midi.de      445
# 329  https://RosiStreams.com      420
# 330  https://RosiStreams.com      420

# %% [markdown]
# ### Delete

# %%
# Last 5 for reference
music_list.tail(3)
# Out:
#       composer                   composition    movement    ensemble  \
# 328  Beethoven  Piano Sonata No 9 in E major  1. Allegro  Solo Piano
# 329     Chopin            Ballade in G minor   4. Sonata  Solo Piano
# 330     Chopin            Ballade in G minor   4. Sonata  Solo Piano
#
#                  transcriber  seconds
# 328            piano-midi.de      445
# 329  https://RosiStreams.com      420
# 330  https://RosiStreams.com      420

# %%
# Can pass a single index or an array of indeces
music_list.delete([329, 330])
music_list.tail(3)
# Out:
#       composer                     composition                   movement  \
# 326  Beethoven   Piano Sonata No 10 in G major  3. Scherzo: Allegro assai
# 327       Bach  Violin Partita No 1 in B minor                  6. Double
# 328  Beethoven    Piano Sonata No 9 in E major                 1. Allegro
#
#         ensemble    transcriber  seconds
# 326   Solo Piano  piano-midi.de      227
# 327  Solo Violin       suzumidi      108
# 328   Solo Piano  piano-midi.de      445

# %% [markdown]
# ### General Queries

# %%
music_list.sort_values(by=['composer'])
# Out:
#      composer                                      composition  \
# 164      Bach  WTK I, No. 8: Prelude and Fugue in E-flat minor
# 129      Bach                                    Cello Suite 3
# 130      Bach                                    Cello Suite 3
# 131      Bach                                    Cello Suite 3
# 132      Bach  WTK I, No. 7: Prelude and Fugue in E-flat major
# ..        ...                                              ...
# 27   Schubert                          Piano Sonata in D major
# 28   Schubert                          Piano Sonata in D major
# 29   Schubert                          Piano Sonata in D major
# 15   Schubert                          Piano Sonata in C minor
# 0    Schubert                         Piano Quintet in A major
#
#                        movement       ensemble  \
# 164                  1. Prelude     Solo Piano
# 129                4. Sarabande     Solo Cello
# 130                   5. Bouree     Solo Cello
# 131                    6. Gigue     Solo Cello
# 132                    2. Fugue     Solo Piano
# ..                          ...            ...
# 27            1. Allegro vivace     Solo Piano
# 28                  2. Con moto     Solo Piano
# 29   3. Scherzo. Allegro vivace     Solo Piano
# 15                   1. Allegro     Solo Piano
# 0                    2. Andante  Piano Quintet
#
#                          transcriber  seconds
# 164              www.bachcentral.com      238
# 129                David J. Grossman      302
# 130                David J. Grossman      241
# 131                David J. Grossman      202
# 132              www.bachcentral.com      108
# ..                               ...      ...
# 27                 Segundo G. Yogore      578
# 28                 Segundo G. Yogore      726
# 29                 Segundo G. Yogore      629
# 15           Martin Charles Bucknall      710
# 0    http://tirolmusic.blogspot.com/      447
#
# [329 rows x 6 columns]

# %%
music_list.loc[music_list['composer'] == 'Bach']
# Out:
#     composer                                        composition     movement  \
# 106     Bach                     Violin Partita No 3 in E major  1. Preludio
# 107     Bach                     Violin Partita No 3 in E major   6. Bourree
# 108     Bach  WTK I, No. 13: Prelude and Fugue in F-sharp major   1. Prelude
# 109     Bach   WTK I, No. 3: Prelude and Fugue in C-sharp major     2. Fugue
# 110     Bach   WTK I, No. 3: Prelude and Fugue in C-sharp major   1. Prelude
# ..       ...                                                ...          ...
# 168     Bach  WTK I, No. 14: Prelude and Fugue in F-sharp minor   1. Prelude
# 169     Bach  WTK I, No. 18: Prelude and Fugue in G-sharp minor     2. Fugue
# 170     Bach  WTK I, No. 18: Prelude and Fugue in G-sharp minor   1. Prelude
# 171     Bach        WTK I, No. 15: Prelude and Fugue in G major   1. Prelude
# 327     Bach                     Violin Partita No 1 in B minor    6. Double
#
#         ensemble          transcriber  seconds
# 106  Solo Violin             suzumidi      214
# 107  Solo Violin             suzumidi      102
# 108   Solo Piano  www.bachcentral.com      100
# 109   Solo Piano  www.bachcentral.com      155
# 110   Solo Piano  www.bachcentral.com       75
# ..           ...                  ...      ...
# 168   Solo Piano  www.bachcentral.com       65
# 169   Solo Piano  www.bachcentral.com      137
# 170   Solo Piano  www.bachcentral.com      121
# 171   Solo Piano  www.bachcentral.com       55
# 327  Solo Violin             suzumidi      108
#
# [67 rows x 6 columns]

# %%
music_list.loc[music_list['seconds'] < 200]
# Out:
#       composer                         composition  \
# 17    Schubert             Piano Sonata in C minor
# 43      Mozart            Serenade in E-flat major
# 92      Brahms  String Sextet No 1 in B-flat major
# 99       Faure       Piano Quartet No 2 in G minor
# 107       Bach      Violin Partita No 3 in E major
# ..         ...                                 ...
# 287  Beethoven       Piano Sonata No 30 in E major
# 306  Beethoven  Piano Sonata No 12 in A-flat major
# 318  Beethoven        Piano Sonata No 6 in F major
# 323  Beethoven      Violin Sonata No 10 in G major
# 327       Bach      Violin Partita No 1 in B minor
#
#                        movement                     ensemble  \
# 17         3. Menuetto and Trio                   Solo Piano
# 43                  4. Menuetto  Pairs Clarinet-Horn-Bassoon
# 92    3. Scherzo. Allegro molto                String Sextet
# 99             2. Allegro molto                Piano Quartet
# 107                  6. Bourree                  Solo Violin
# ..                          ...                          ...
# 287              2. Prestissimo                   Solo Piano
# 306                  4. Allegro                   Solo Piano
# 318                   3. Presto                   Solo Piano
# 323  3. Scherzo: Allegro - Trio           Accompanied Violin
# 327                   6. Double                  Solo Violin
#
#                  transcriber  seconds
# 17   Martin Charles Bucknall      194
# 43              Oliver Seely      177
# 92              harfesoft.de      192
# 99        Gregory Richardson      193
# 107                 suzumidi      102
# ..                       ...      ...
# 287            piano-midi.de      151
# 306            piano-midi.de      179
# 318            piano-midi.de      159
# 323                suzumedia      124
# 327                 suzumidi      108
#
# [65 rows x 6 columns]

# %% [markdown]
# ### Song Randomizer

# %%
SongRandomizer(music_list)
# Out:
#    composer                composition   movement       ensemble  \
# 8  Schubert  String Quintet in C major  2. Adagio  Viola Quintet
#
#     transcriber  seconds
# 8  harfesoft.de      924

# %% [markdown]
# ## Empty the DataFrame
# \
# \> music_list.kaboom()

# %%
music_list.kaboom()

# %%
music_list.read()
# Out:
# Empty CRUD
# Columns: [composer, composition, movement, ensemble, transcriber, seconds]
# Index: []

# %% [markdown]
# ## Extra Credit
# #### I started out this project taking into account my personal interest, which is playing the kalimba. I needed a way to compile different compositions for me to learn and play, while also being able to sort by the columns, and randomly generate a song from the list. By incorporating the CRUD operations method with an existing music DataBase, I'm able to make an original DataBase (ref. "Empty the DataFrame"). I looked into how CRUD operations are used to manage data throughout web and desktop applications, machine learning models, and for data analysis. The most draining part of this project was really starting it out, but importing the databases and making sure that the code still worked after applying proper formatting (e.g. the numpy docstrings with Indentation Errors) was also a frustrating process. By using pandas.DataFrame I had to familiarize myself with commands like .iloc, .loc, .drop, .update, .reindex, while evaluating the creation of new code. Although I was already familiar with importing operations and libraries like pandas through this introductory course, the "from __ import ___" lines constantly gave me trouble as well because of how easily I forgot to save + restart kernel to run all after updating the classes, functions, and methods with new information. Working with so many documents like test notebooks, py files, txt files, and csvs was overwhelming and I needed multiple tabs open constantly so that I could go back and look into what was originally written, the original plans, and what was realistic within the final project deadline.
#
# ## DataBase Test Credit
# ### MusicNet Dataset, by Gupta, Sparsh
# #### Music from the Dataset is sourced from Isabella Stewart Gardner Museum, the European Archive, and Musopen.
#
# https://www.kaggle.com/datasets/imsparsh/musicnet-dataset/
#
# https://storage.googleapis.com/kagglesdsdata/datasets/1167622/1956211/musicnet_metadata.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20231211%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20231211T043119Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
